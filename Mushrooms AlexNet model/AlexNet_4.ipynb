# %% [markdown]
# <a href="https://colab.research.google.com/github/grullaandrea-png/mushroom_classification_model_dervishi/blob/main/AlexNet_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/dataset_locale/
# !unzip -q "/content/drive/MyDrive/Deep_learning_project/archive (9).zip" -d "/content/dataset_locale/"

import os
# Stampiamo cosa c'è dentro la cartella per vedere il nome esatto della sottocartella!
print("Contenuto della cartella estratta:")
print(os.listdir("/content/dataset_locale/"))
# Out:
# Contenuto della cartella estratta:
# ['Data']

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
import torch

data_dir = "/content/dataset_locale/Data"

# 1. Definisci le trasformazioni (as ResNet18)
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(brightness=0.1, contrast=0.1),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

full_dataset = datasets.ImageFolder(root=data_dir)


# 3. Dividi in 70% Train, 20% Test, 10% Validation
total_size = len(full_dataset)
train_size = int(0.70 * total_size)
test_size = int(0.20 * total_size)
val_size = total_size - train_size - test_size

train_raw, test_raw, val_raw = random_split(full_dataset, [train_size, test_size, val_size])

# 4. Classe per applicare la trasformazione giusta al gruppo giusto
class ApplyTransform(torch.utils.data.Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y

    def __len__(self):
        return len(self.subset)

# 5. Applica le trasformazioni: nota come ora peschiamo la chiave 'train' o 'val' dal dizionario
train_dataset = ApplyTransform(train_raw, transform=data_transforms['train'])
val_dataset = ApplyTransform(val_raw, transform=data_transforms['val'])
test_dataset = ApplyTransform(test_raw, transform=data_transforms['val'])

# 6. Crea i DataLoader finali
batch_size = 32

# Usa 2 o 4 worker (processi paralleli) per leggere le foto, e pin_memory per trasferirle velocemente alla GPU
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)

print(f"Immagini per Training: {len(train_dataset)}")
print(f"Immagini per Validation: {len(val_dataset)}")
print(f"Immagini per Test: {len(test_dataset)}")
# Out:
# Immagini per Training: 8400
# Immagini per Validation: 1200
# Immagini per Test: 2400

# %%
import torch
from torch import nn

net = nn.Sequential(
    # 1. Conv
    nn.Conv2d(3, 96, kernel_size=11, stride=4, padding=1),
    nn.BatchNorm2d(96), # <--- AGGIUNTO
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),

    # 2. Conv
    nn.Conv2d(96, 256, kernel_size=5, padding=2),
    nn.BatchNorm2d(256), # <--- AGGIUNTO
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),

    # 3, 4, 5 Conv
    nn.Conv2d(256, 384, kernel_size=3, padding=1),
    nn.BatchNorm2d(384), # <--- AGGIUNTO
    nn.ReLU(),

    nn.Conv2d(384, 384, kernel_size=3, padding=1),
    nn.BatchNorm2d(384), # <--- AGGIUNTO
    nn.ReLU(),

    nn.Conv2d(384, 256, kernel_size=3, padding=1),
    nn.BatchNorm2d(256), # <--- AGGIUNTO
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),

    nn.Flatten(),
    nn.Linear(6400, 4096), nn.ReLU(),
    nn.Dropout(p=0.5), # Lascia il dropout a 0.5 per sicurezza
    nn.Linear(4096, 4096), nn.ReLU(),
    nn.Dropout(p=0.5),
    nn.Linear(4096, 12)
)

# %%
# Installa la libreria (necessario solo la prima volta o se riavvii l'ambiente)
# !pip install d2l==1.0.a1.post0
from d2l import torch as d2l  # Qui definiamo il nome 'd2l'
# Out:
# Collecting d2l==1.0.a1.post0
#   Downloading d2l-1.0.0a1.post0-py3-none-any.whl.metadata (489 bytes)
# Collecting jupyter (from d2l==1.0.a1.post0)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from d2l==1.0.a1.post0) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from d2l==1.0.a1.post0) (3.10.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from d2l==1.0.a1.post0) (0.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from d2l==1.0.a1.post0) (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from d2l==1.0.a1.post0) (2.2.2)
# Requirement already satisfied: gym in /usr/local/lib/python3.12/dist-packages (from d2l==1.0.a1.post0) (0.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gym->d2l==1.0.a1.post0) (3.1.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym->d2l==1.0.a1.post0) (0.1.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter->d2l==1.0.a1.post0) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter->d2l==1.0.a1.post0) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter->d2l==1.0.a1.post0) (7.17.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from jupyter->d2l==1.0.a1.post0) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from jupyter->d2l==1.0.a1.post0) (7.7.1)
# Collecting jupyterlab (from jupyter->d2l==1.0.a1.post0)
#   Downloading jupyterlab-4.5.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->d2l==1.0.a1.post0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->d2l==1.0.a1.post0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->d2l==1.0.a1.post0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->d2l==1.0.a1.post0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->d2l==1.0.a1.post0) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->d2l==1.0.a1.post0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->d2l==1.0.a1.post0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->d2l==1.0.a1.post0) (2.9.0.post0)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from matplotlib-inline->d2l==1.0.a1.post0) (5.7.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->d2l==1.0.a1.post0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->d2l==1.0.a1.post0) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->d2l==1.0.a1.post0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->d2l==1.0.a1.post0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->d2l==1.0.a1.post0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->d2l==1.0.a1.post0) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->d2l==1.0.a1.post0) (1.17.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->d2l==1.0.a1.post0) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->d2l==1.0.a1.post0) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->d2l==1.0.a1.post0) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->d2l==1.0.a1.post0) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->d2l==1.0.a1.post0) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->d2l==1.0.a1.post0) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->d2l==1.0.a1.post0) (6.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->d2l==1.0.a1.post0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->d2l==1.0.a1.post0) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->d2l==1.0.a1.post0) (3.0.16)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter->d2l==1.0.a1.post0) (5.9.1)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter->d2l==1.0.a1.post0) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter->d2l==1.0.a1.post0) (2.19.2)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->d2l==1.0.a1.post0)
#   Downloading async_lru-2.2.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->d2l==1.0.a1.post0) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->d2l==1.0.a1.post0) (3.1.6)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->d2l==1.0.a1.post0)
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->d2l==1.0.a1.post0) (2.14.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab->jupyter->d2l==1.0.a1.post0)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->d2l==1.0.a1.post0) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->d2l==1.0.a1.post0) (75.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->d2l==1.0.a1.post0) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->d2l==1.0.a1.post0) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->d2l==1.0.a1.post0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->d2l==1.0.a1.post0) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->d2l==1.0.a1.post0) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->d2l==1.0.a1.post0) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->d2l==1.0.a1.post0) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->d2l==1.0.a1.post0) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->d2l==1.0.a1.post0) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->d2l==1.0.a1.post0) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->d2l==1.0.a1.post0) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->d2l==1.0.a1.post0) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->d2l==1.0.a1.post0) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->d2l==1.0.a1.post0) (1.3.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->d2l==1.0.a1.post0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->d2l==1.0.a1.post0) (1.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (0.16.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.a1.post0)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.a1.post0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.a1.post0) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.a1.post0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.a1.post0) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->d2l==1.0.a1.post0) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->d2l==1.0.a1.post0) (4.9.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter->d2l==1.0.a1.post0) (25.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (2.18.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.a1.post0)
#   Downloading json5-0.13.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (4.26.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert->jupyter->d2l==1.0.a1.post0) (2.21.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->d2l==1.0.a1.post0) (0.6.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook->jupyter->d2l==1.0.a1.post0) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter->d2l==1.0.a1.post0) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter->d2l==1.0.a1.post0) (4.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->d2l==1.0.a1.post0) (0.8.6)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (0.1.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->d2l==1.0.a1.post0) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->d2l==1.0.a1.post0) (3.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->d2l==1.0.a1.post0) (1.4.0)
# Downloading d2l-1.0.0a1.post0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 7.1 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyterlab-4.5.5-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 119.5 MB/s eta 0:00:00
# Downloading async_lru-2.2.0-py3-none-any.whl (7.9 kB)
# Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 9.6 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.9 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.1 MB/s eta 0:00:00
# Downloading json5-0.13.0-py3-none-any.whl (36 kB)
# Installing collected packages: json5, jedi, async-lru, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter, d2l
# Successfully installed async-lru-2.2.0 d2l-1.0.0a1.post0 jedi-0.19.2 json5-0.13.0 jupyter-1.1.1 jupyter-lsp-2.3.0 jupyterlab-4.5.5 jupyterlab-server-2.28.0

# %%
import torch
from d2l import torch as d2l

def evaluate_accuracy_gpu(net, data_iter, device=None):
    """Calcola l'accuratezza del modello su un dataset usando la GPU."""
    if isinstance(net, torch.nn.Module):
        net.eval()  # Mette la rete in modalità valutazione (disattiva il Dropout)
        if not device:
            device = next(iter(net.parameters())).device

    metric = d2l.Accumulator(2)

    with torch.no_grad(): # Disattiva il calcolo dei gradienti per risparmiare memoria
        for X, y in data_iter:
            if isinstance(X, list):
                X = [x.to(device) for x in X]
            else:
                X = X.to(device)
            y = y.to(device)
            metric.add(d2l.accuracy(net(X), y), y.numel())

    return metric[0] / metric[1]

print("Funzione 'evaluate_accuracy_gpu' caricata correttamente!")

def train_mushrooms(net, train_loader, val_loader, num_epochs, lr, device=d2l.try_gpu()):
    # 1. Inizializzazione pesi (Xavier)
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)

    net.apply(init_weights)
    print('Training su:', device)
    net.to(device)

    # 2. Ottimizzatore AdamW + Scheduler
    optimizer = torch.optim.AdamW(net.parameters(), lr=lr, weight_decay=0.05)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=4)

    loss = nn.CrossEntropyLoss()
    animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
                            legend=['train loss', 'train acc', 'val acc'])

    timer, num_batches = d2l.Timer(), len(train_loader)

    for epoch in range(num_epochs):
        metric = d2l.Accumulator(3)
        net.train()

        for i, (X, y) in enumerate(train_loader):
            timer.start()
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)

            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()

            # --- IL PARACADUTE: GRADIENT CLIPPING ---
            # Impedisce ai gradienti di esplodere, evitando che la loss diventi altissima
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=1.0)

            optimizer.step()

            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            timer.stop()

            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]

            if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
                animator.add(epoch + (i + 1) / num_batches, (train_l, train_acc, None))

        val_acc = evaluate_accuracy_gpu(net, val_loader)
        animator.add(epoch + 1, (None, None, val_acc))

        # --- POSIZIONE CORRETTA DELLO SCHEDULER ---
        # Si aggiorna DOPO che l'epoca è finita
        scheduler.step(val_acc)

        # Stampa il Learning Rate attuale per monitorare lo scheduler
        current_lr = optimizer.param_groups[0]['lr']
        print(f'Epoca {epoch+1}: Loss {train_l:.3f}, Train Acc {train_acc:.3f}, Val Acc {val_acc:.3f}, LR {current_lr:.6f}')
# Out:
# Funzione 'evaluate_accuracy_gpu' caricata correttamente!

# %%
# 1. Definiamo i parametri (Learning Rate e Numero di Epoche)
lr, num_epochs = 0.0002, 50

# 2. Lanciamo la funzione di addestramento
# net: la tua AlexNet a 12 classi
# train_loader: i dati per imparare (70%)
# val_loader: i dati per controllare (10%) - Usiamo val_loader qui, non test_loader!
train_mushrooms(net, train_loader, val_loader, num_epochs, lr, device=d2l.try_gpu())
# Out:
# Epoca 50: Loss 0.243, Train Acc 0.919, Val Acc 0.676, LR 0.000200

# %%
save_path = '/content/drive/MyDrive/Deep_learning_project/mushroom_alexnet4.pth'

# %% [markdown]
# **Confusion matrix**
#
# >

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 1. Prepariamo le liste per salvare i risultati
y_true = []
y_scores = []
y_pred = []

print("Calcolo delle predizioni in corso sul TEST SET...")

# Mettiamo la rete in modalità valutazione (disattiva il Dropout)
net.eval()

# 2. Estraiamo le predizioni usando il TEST_LOADER
with torch.no_grad():
    for X, y in test_loader:  # <--- SOSTITUITO QUI
        X = X.to(d2l.try_gpu())
        outputs = net(X)

        # Calcoliamo le probabilità (Softmax)
        probs = torch.nn.functional.softmax(outputs, dim=1)
        # Prendiamo la classe con probabilità più alta
        preds = torch.argmax(probs, dim=1)

        y_true.extend(y.cpu().numpy())
        y_scores.extend(probs.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# Convertiamo in array numpy per comodità
y_true = np.array(y_true)
y_scores = np.array(y_scores)
y_pred = np.array(y_pred)

# Recuperiamo i nomi delle classi dal dataset
class_names = full_dataset.classes

# 3. Disegniamo la Matrice di Confusione
plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Classe Predetta (dal Modello)', fontsize=12)
plt.ylabel('Classe Reale (Vera)', fontsize=12)
plt.title('Matrice di Confusione sul Test Set - AlexNet', fontsize=15)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Calcolo delle predizioni in corso sul TEST SET...

# %% [markdown]
# **ROC Curve**

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

n_classes = len(class_names)

# 1. Binarizziamo le etichette reali (necessario per ROC multiclasse: One-vs-Rest)
y_true_bin = label_binarize(y_true, classes=range(n_classes))

# 2. Prepariamo il grafico
plt.figure(figsize=(12, 8))

# Disegniamo una curva ROC per ogni singola classe
for i in range(n_classes):
    # Calcoliamo i falsi positivi (fpr) e veri positivi (tpr) per la classe 'i'
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
    roc_auc = auc(fpr, tpr)

    # Aggiungiamo la linea al grafico
    plt.plot(fpr, tpr, lw=2, label=f'{class_names[i]} (AUC = {roc_auc:.2f})')

# Disegniamo la linea diagonale tratteggiata (classificatore puramente casuale)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

# Dettagli estetici del grafico
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (Tasso di Falsi Positivi)', fontsize=12)
plt.ylabel('True Positive Rate (Tasso di Veri Positivi)', fontsize=12)
plt.title('Curva ROC e AUC sul Test Set - AlexNet', fontsize=15)
plt.legend(loc="lower right", fontsize=10, ncol=2)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
